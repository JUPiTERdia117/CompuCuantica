# %%
from qiskit import QuantumCircuit, QuantumRegister

# %%
import numpy as np
circ1 = QuantumCircuit(1) # circuito con 1 qubit

psi_0 = Statevector(circ1)   # estado justo después de crear el circuito

print("👉 Estado inicial:")
print("➤ en forma de vector:")
display(array_to_latex(psi_0.data))

circ1.x(0)                # aplicar compuerta X al (único) qubit 0

psi_x = Statevector(circ1)   # estado después de aplicar compuerta x

print("👉 Estado después de aplicar x:")
print("➤ en forma de vector:")
display(array_to_latex(psi_x.data))

circ1.y(0)

psi_y = Statevector(circ1)   #  estado después de aplicar compuerta y
print("👉 Estado después de aplicar y:")
print("➤ en forma de vector:")
display(array_to_latex(psi_y.data))

circ1.z(0)

psi_z = Statevector(circ1)   # estado después de aplicar compuerta z
print("👉 Estado después de aplicar z:")
print("➤ en forma de vector:")
display(array_to_latex(psi_z.data))

circ1.h(0)

psi_h = Statevector(circ1)   #  estado después de aplicar compuerta h
print("👉 Estado después de aplicar h:")
print("➤ en forma de vector:")
display(array_to_latex(psi_h.data))

circ1.ry(np.pi/2, 0)         # rotar pi/2 alrededor del eje y

psi_ry = Statevector(circ1)   #  estado después de aplicar compuerta ry
print("👉 Estado después de aplicar ry:")
print("➤ en forma de vector:")
display(array_to_latex(psi_ry.data))

circ1.draw('mpl')         # mostrar el circuito
# Out:
# 👉 Estado inicial:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$
# 👉 Estado después de aplicar x:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
# 👉 Estado después de aplicar y:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# - i & 0  \\
#  \end{bmatrix}
# $$
# 👉 Estado después de aplicar z:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# - i & 0  \\
#  \end{bmatrix}
# $$
# 👉 Estado después de aplicar h:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# - \frac{\sqrt{2} i}{2} & - \frac{\sqrt{2} i}{2}  \\
#  \end{bmatrix}
# $$
# 👉 Estado después de aplicar ry:
# ➤ en forma de vector:
# $$
#
# \begin{bmatrix}
# 0 & - i  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# # Lo que le sucede al qubit
#
# Partimos del estado inicial de un solo qubit, que es el estado |0⟩
#
# ---
#
# ## 1.- Aplicando Compuerta X
#
# La compuerta X es equivalente a un NOT cuántico. Su matriz es:
#
#
# \begin{pmatrix}
# 0 & 1 \\
# 1 & 0
# \end{pmatrix}
#
# Resultado:
#
#
# \begin{pmatrix}
# 0 \\
# 1
# \end{pmatrix}
#
# Podemos observar que se convierte en el estado 1.
#
#
# ---
#
# ## 2.- Compuerta Y
#
# Matriz:
#
#
# \begin{pmatrix}
# 0 & -i \\
# i & 0
# \end{pmatrix}
#
# Aplicada sobre |1⟩:
#
#
# \begin{pmatrix}
# -i  \\
# 0
# \end{pmatrix}
#
#
# Rotación de π alrededor del eje Y. Aparece una fase global (-i) que es físicamente equivalente a |0⟩.
#
# ---
#
# ## 3.- Compuerta Z
#
# Matriz:
#
#
# \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}
#
#
# Aplicada sobre |0⟩:
#
#
# \begin{pmatrix}
# -i  \\
# 0
# \end{pmatrix}
#
#
# Con esto rota π radianes alrededor del eje Z.
# No altera |0⟩.
#
# ---
#
# ## 4.- Compuerta H (Hadamard)
#
# Matriz:
#
#
#
# \begin{pmatrix}
# 1 & 1 \\
# 1 & -1
# \end{pmatrix}
#
#
# Aplicada sobre |0⟩:
#
#
# \begin{pmatrix}
# 1 \\
# 1
# \end{pmatrix}
#
#
# Lleva el estado a superposición. Se convierte en el estado |+⟩
#
# ---
#
# ## 5.-Rotación RY(π/2)
#
# Matriz general:
#
#
# \begin{pmatrix}
# \cos(\theta/2) & -\sin(\theta/2) \\
# \sin(\theta/2) & \cos(\theta/2)
# \end{pmatrix}
#
#
# Para θ = π/2:
#
# \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}
#
#
# Esta compuerta rota el estado π/2 radianes alrededor del eje Y. Cambia las probabilidades de medir |0⟩ y |1⟩. Convierte el vector a
# \begin{pmatrix}
# 0 \\
# -i
# \end{pmatrix}
#
#
# Que físicamente es equivalente al estado |1⟩

# %% [markdown]
# # Operación completa
#
# $$
# |\psi_{\text{final}}\rangle
# =
# \begin{pmatrix}
# \cos\frac{\pi}{4} & -\sin\frac{\pi}{4}\\
# \sin\frac{\pi}{4} & \cos\frac{\pi}{4}
# \end{pmatrix}
# \frac{1}{\sqrt{2}}
# \begin{pmatrix}
# 1 & 1\\
# 1 & -1
# \end{pmatrix}
# \begin{pmatrix}
# 1 & 0\\
# 0 & -1
# \end{pmatrix}
# \begin{pmatrix}
# 0 & -i\\
# i & 0
# \end{pmatrix}
# \begin{pmatrix}
# 0 & 1\\
# 1 & 0
# \end{pmatrix}
# |\psi_0\rangle
# $$

# %% [markdown]
# # Cuenta de IBM
# !["Cuenta de ibm"](CuentaIBM.png)
# !["Circuito de Composser"](Circuito.png)
